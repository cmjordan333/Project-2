# %%
#Funky fresh imports!
import pandas as pd
from pandas import DataFrame
import requests
from bs4 import BeautifulSoup

# %%
#Mic Check 1 2 1 2
url = 'https://www.lyrics.com/artist/Public+Enemy/86'
req = requests.get(url)
soup = BeautifulSoup(req.text, 'html.parser')

# %%
#Where my albums at?!
albums = soup.find_all('h3', {'class': 'artist-album-label'})

# %%
# Throw your i in the air and print like you just don't care!
for i in albums[:5]:
    print(i.text)
# Out:
# Yo! Bum Rush the Show [1987]
# It Takes a Nation of Millions To Hold Us Back [1988]
# Fear of a Black Planet [1990]
# Fear of a Black Planet [1990]
# Rap's Biggest Hits [1990]

# %%
#Find the songs
songs = soup.find_all('td',{'class': 'tal qx'})

# %%
for i in songs[::2][:5]:
    print(i.text)
# Out:
# M.P.E.
# Megablast
# Miuzi Weighs a Ton
# Public Enemy No. 1
# Raise the Roof

# %%
#More junk in the Truncation:
#https://www.lyrics.com/lyric/13976227/Beastie+Boys/And+What+You+Give+Is+What+You+Get
#Meaning the link above is a reference to the Song Title and Lyrics for the song
songs[0].a.attrs['href']
# Out:
# '/lyric/1447193/Public+Enemy/M.P.E.'

# %%
#DJ crank the BASE...url.
url = 'https://www.lyrics.com'

# %%
lyrics = url + songs[0].a.attrs['href']

# %%
#
def lookup():
    #It takes a second to get the results intp a df, so hold tight!
    artist = input("Find the artist! (and be patient!)  ")
    if len(artist.split()) < 2:
        #If there are more than two artists with the same name, add a way to tell them apart
        url = 'https://www.lyrics.com/artist/' + artist.split(' ')[0].lower()
    else:
        url = 'https://www.lyrics.com/artist/' + artist.split(' ')[0].lower()
    for i in range(1, len(artist.split())):
        url = url + '%20' + artist.split(' ')[i].lower()
    req = requests.get(url)
    soup = BeautifulSoup(req.text, 'html.parser')
    alb = []
    #art = []
    s = []
    albums = soup.find_all('h3', {'class': 'artist-album-label'})
    for i in albums:
        alb.append(i.text)
    songs = soup.find_all('td',{'class': 'tal qx'})
    for i in songs[::2]:
        s.append(i.text)
    #for i in artist:
        #art.append(i.text)
    #for i in songs[1::2]:
       # ti.append(i.text)
    base = 'https://www.lyrics.com'
    l = []
    for i in range(len(songs)):
        if songs[i].a is None:
            pass
        else:
            lyrics = base + songs[i].a.attrs['href']
            url = lyrics
            req = requests.get(url)
            soup = BeautifulSoup(req.text, 'html.parser')
            l.append(soup.find('pre', {'id': 'lyric-body-text'}).text)
    df = pd.DataFrame({'song': s, 'lyrics': l }) #'Time':ti | 'Artist': art,
    return df

# %%
#Public+Enemy
lookup()
# Out:
# Find the artist! (and be patient!)  Public+Enemy
#                                                   song  \
# 0                                               M.P.E.
# 1                                            Megablast
# 2                                   Miuzi Weighs a Ton
# 3                                   Public Enemy No. 1
# 4                                       Raise the Roof
# 5                Rightstarter (Message to a Black Man)
# 6                                  Sophisticated Bitch
# 7                   Terminator X Speaks with His Hands
# 8                                             Timebomb
# 9                                       Too Much Posse
# 10                               Yo! Bum Rush the Snow
# 11                              You're Gonna Get Yours
# 12                    Black Steel in the Hour of Chaos
# 13                       Caught, Can We Get a Witness?
# 14                            Cold Lampin' with Flavor
# 25   Uh, your bad self\r\nHelp me break this down f...
# 26   Burn Hollywood burn I smell a riot\r\nGoin' on...
# 27   Runnin' for your life, by the knife\r\nRunnin'...
# 28   Man, don't you worry 'bout a thing\r\n'Bout yo...
# 29   Man to man\r\nI don't know if they can\r\nFrom...
# ..                                                 ...
# 118  You know I, this is James Brown\r\nI'm such a ...
# 119  Bass! How low can you go?\r\nDeath row, what a...
# 120  Moby pemoby pemoby pemoby pe\r\n\r\nJust gonna...
# 121  Today we are together, we are unified and on r...
# 122  Yo Chuck, bust a move man\nI was on my way up ...
# 123  Mind over matter, mouth in motion\nCan't defy,...
# 124  Played in Cincinnati\r\nWith my whole head nap...
# 125  Yet our best trained, best educated, best equi...
# 126  [verse 1]\nPlayed in Cincinnati\nWit my whole ...
# 127  Jump back poppin that track\nGonna wreck it no...
# 128  Jump back poppin' that track \r\nGonna wreck i...
# 129  We was raised in these streets on pork and poi...
# 130  Runnin' for your life, by the knife\r\nRunnin'...
# 131  Well I'm all in, put it up on the board\r\nAno...
# 132  You're blind, baby\r\nYou're blind from the fa...
# 133  Today we are together, we are unified and on r...
# 134  I came from a place I forgot\r\nI woke up in t...
# 135  Yeah that's right Chuck man, that's what you g...
# 136  The eastern world, it is explodin'\r\nViolence...
# 137  What, goes, on!\r\nRolling Stones of the rap g...
# 138  Too black, too strong\r\nToo black, too strong...
# 139  Crosstown traffic\r\nBlack to black\r\nYou sho...
# 140  Damn back again up on track again\r\n? 'round ...
# 141  Aye yo man, ya yo yo yo\r\nI'm tryin' ta stay ...
# 142  Back\r\nCaught you lookin' for the same thing\...
# 143  Hit me\r\n\r\nGoing, going, gone\r\nNow I dial...
# 144  Bass! How low can you go?\r\nDeath row, what a...
# 145  What, goes, on!\r\nRolling Stones of the rap g...
# 146  Here it is\r\nBam!\r\nAnd you say, Goddamn\r\n...
# 147  Yes, the rhythm, the rebel\r\nWithout a pause,...
#
# [148 rows x 2 columns]

# %%
public = lookup()
# Out:
# Find the artist! (and be patient!)  Public+Enemy

# %%
type(public)
# Out:
# pandas.core.frame.DataFrame

# %%
#Passing the Mic
df = pd.DataFrame(public)

# %%
df
# Out:
#                                                   song  \
# 0                                               M.P.E.
# 1                                            Megablast
# 2                                   Miuzi Weighs a Ton
# 3                                   Public Enemy No. 1
# 4                                       Raise the Roof
# 5                Rightstarter (Message to a Black Man)
# 6                                  Sophisticated Bitch
# 7                   Terminator X Speaks with His Hands
# 8                                             Timebomb
# 9                                       Too Much Posse
# 10                               Yo! Bum Rush the Snow
# 11                              You're Gonna Get Yours
# 12                    Black Steel in the Hour of Chaos
# 13                       Caught, Can We Get a Witness?
# 14                            Cold Lampin' with Flavor
# 15                              Don't Believe the Hype
# 16                                      Mind Terrorist
# 17                       Night of the Living Baseheads
# 18                       Party for Your Right to Fight
# 19                                    Prophets of Rage
# 20                            She Watch Channel Zero?!
# 21                   Terminator X to the Edge of Panic
# 22                                       911 Is a Joke
# 23                                 Anti-Nigger Machine
# 24                                   B Side Wins Again
# 25                          Brothers Gonna Work It Out
# 26                                 Burn Hollywood Burn
# 119  Bass! How low can you go?\r\nDeath row, what a...
# 120  Moby pemoby pemoby pemoby pe\r\n\r\nJust gonna...
# 121  Today we are together, we are unified and on r...
# 122  Yo Chuck, bust a move man\nI was on my way up ...
# 123  Mind over matter, mouth in motion\nCan't defy,...
# 124  Played in Cincinnati\r\nWith my whole head nap...
# 125  Yet our best trained, best educated, best equi...
# 126  [verse 1]\nPlayed in Cincinnati\nWit my whole ...
# 127  Jump back poppin that track\nGonna wreck it no...
# 128  Jump back poppin' that track \r\nGonna wreck i...
# 129  We was raised in these streets on pork and poi...
# 130  Runnin' for your life, by the knife\r\nRunnin'...
# 131  Well I'm all in, put it up on the board\r\nAno...
# 132  You're blind, baby\r\nYou're blind from the fa...
# 133  Today we are together, we are unified and on r...
# 134  I came from a place I forgot\r\nI woke up in t...
# 135  Yeah that's right Chuck man, that's what you g...
# 136  The eastern world, it is explodin'\r\nViolence...
# 137  What, goes, on!\r\nRolling Stones of the rap g...
# 138  Too black, too strong\r\nToo black, too strong...
# 139  Crosstown traffic\r\nBlack to black\r\nYou sho...
# 140  Damn back again up on track again\r\n? 'round ...
# 141  Aye yo man, ya yo yo yo\r\nI'm tryin' ta stay ...
# 142  Back\r\nCaught you lookin' for the same thing\...
# 143  Hit me\r\n\r\nGoing, going, gone\r\nNow I dial...
# 144  Bass! How low can you go?\r\nDeath row, what a...
# 145  What, goes, on!\r\nRolling Stones of the rap g...
# 146  Here it is\r\nBam!\r\nAnd you say, Goddamn\r\n...
# 147  Yes, the rhythm, the rebel\r\nWithout a pause,...
#
# [148 rows x 2 columns]

# %%
#1 2 1 2...this is just a (CSV)test
df.to_csv('public_lyrics.csv')

# %%
#Pass me the J, SON!
df.to_json(r'JSONLyricsExports\snoop_lyrics.json')

# %%
#Raw Word Count
df.lyrics.str.split(expand=True).stack().value_counts()
# Out:
# the              3632
# a                1593
# I                1456
# to               1417
# you              1081
# it               1003
# and               836
# of                760
# in                750
# on                686
# is                543
# I'm               510
# that              484
# got               470
# for               470
# get               464
# me                463
# my                435
# be                359
# your              358
# up                351
# we                351
# And               350
# The               346
# like              345
# they              341
# what              339
# know              323
# don't             295
# But               262
#                  ...
# y'all"              1
# hah,                1
# raising             1
# 66                  1
# L,                  1
# smile,              1
# consume             1
# championships       1
# settle              1
# revolution,         1
# needles             1
# ratta               1
# continuously        1
# rehearsin           1
# press-              1
# methods             1
# J                   1
# Revolutioned        1
# resorted            1
# Highlighted         1
# cash,               1
# Threat              1
# for.                1
# DayDay              1
# game's              1
# wavin'              1
# ballplayer          1
# Hobbies             1
# Count               1
# bulletproof         1
# Length: 8774, dtype: int64

# %%
wordcount = df.lyrics.str.split(expand=True).stack().value_counts()

# %%
#Word.
pd.DataFrame(wordcount).to_csv('public_words.csv')
#wordcount.rename(columns={'Word':'Count'}, inplace=True)

# %%
#Now a value count without stop words and punctuation
df.replace(to_replace = 'I', 'the', value = "",regex=True)

# %%
#Now a value count without stop words and punctuation
 df.replace(to_replace='the','I','a','you','me','my','and','in','I''m','on','it','of','be','for','get','with','we','that','your','is','they','got','up'value="",regex=True)
