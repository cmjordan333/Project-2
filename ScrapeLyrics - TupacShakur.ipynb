# %%
#Funky fresh imports!
import pandas as pd
from pandas import DataFrame
import requests
from bs4 import BeautifulSoup

# %%
#Mic Check 1 2 1 2
url = 'https://www.lyrics.com/artist/Tupac+Shakur'
req = requests.get(url)
soup = BeautifulSoup(req.text, 'html.parser')

# %%
#Where my albums at?!
albums = soup.find_all('h3', {'class': 'artist-album-label'})

# %%
# Throw your i in the air and print like you just don't care!
for i in albums[:5]:
    print(i.text)
# Out:
# Live at the House of Blues
# Rap-A-Lot 25th Anniversary
# Street Tracks, Vol. 80
# All Eyez on Me [DualDisc] [1996]
# Legends [1997]

# %%
#Find the songs
songs = soup.find_all('td',{'class': 'tal qx'})

# %%
for i in songs[::2][:5]:
    print(i.text)
# Out:
# All About Youw/ 2Pac, Outlawz
# Freek'n Youw/ 2Pac, K-Ci & JoJo, Outlawz
# Never Call You Bitch Againw/ 2Pac, Outlawz
# Troublesomew/ 2Pac, Outlawz
# Homies & Thugsw/ Master P, Scarface

# %%
#More junk in the Truncation:
#https://www.lyrics.com/lyric/13976227/Beastie+Boys/And+What+You+Give+Is+What+You+Get
#Meaning the link above is a reference to the Song Title and Lyrics for the song
songs[0].a.attrs['href']
# Out:
# '/lyric/19393213/2Pac/All+About+You'

# %%
#DJ crank the BASE...url.
url = 'https://www.lyrics.com'

# %%
lyrics = url + songs[0].a.attrs['href']

# %%
#
def lookup():
    #It takes a second to get the results intp a df, so hold tight!
    artist = input("Find the artist! (and be patient!)  ")
    if len(artist.split()) < 2:
        #If there are more than two artists with the same name, add a way to tell them apart
        url = 'https://www.lyrics.com/artist/' + artist.split(' ')[0].lower()
    else:
        url = 'https://www.lyrics.com/artist/' + artist.split(' ')[0].lower()
    for i in range(1, len(artist.split())):
        url = url + '%20' + artist.split(' ')[i].lower()
    req = requests.get(url)
    soup = BeautifulSoup(req.text, 'html.parser')
    alb = []
    #art = []
    s = []
    albums = soup.find_all('h3', {'class': 'artist-album-label'})
    for i in albums:
        alb.append(i.text)
    songs = soup.find_all('td',{'class': 'tal qx'})
    for i in songs[::2]:
        s.append(i.text)
    #for i in artist:
        #art.append(i.text)
    #for i in songs[1::2]:
       # ti.append(i.text)
    base = 'https://www.lyrics.com'
    l = []
    for i in range(len(songs)):
        if songs[i].a is None:
            pass
        else:
            lyrics = base + songs[i].a.attrs['href']
            url = lyrics
            req = requests.get(url)
            soup = BeautifulSoup(req.text, 'html.parser')
            l.append(soup.find('pre', {'id': 'lyric-body-text'}).text)
    df = pd.DataFrame({'song': s, 'lyrics': l }) #'Time':ti | 'Artist': art,
    return df

# %%
#Tupac+Shakur
lookup()
# Out:
# Find the artist! (and be patient!)  Tupac+Shakur
#                                                  song  \
# 0                       All About Youw/ 2Pac, Outlawz
# 1            Freek'n Youw/ 2Pac, K-Ci & JoJo, Outlawz
# 2          Never Call You Bitch Againw/ 2Pac, Outlawz
# 3                         Troublesomew/ 2Pac, Outlawz
# 4                 Homies & Thugsw/ Master P, Scarface
# 5                   Thug's Get Lonely Toow/ Nate Dogg
# 6              2 of Amerikaz Most Wantedw/ Snoop Dogg
# 72  [Chorus]\r\nMe and my homies tho\r\nYou know w...
# 73  You're back now at the jack-off hour this is D...
# 74  Woke up one morning out some bomb ass cock\r\n...
# 75  Now here's the perfect niche to let it bubble ...
# 76  Heah hah hah! \r\nI'm serious nigga one of y'a...
# 77  Yeah\r\nAyo\r\nI think y'all gonna like this n...
# 78  [Chorus]\r\nHow do you want it? How does it fe...
# 79  As I look up at the sky\r\nMy mind starts trip...
# 80  Yo be (turn your speakers up man) \r\nTurn you...
# 81  [Repeat: x2]\r\nI won't deny it, I'm a straigh...
# 82  Whats up Boo? Swear I'll never call you bitch ...
# 83  Ah shit ha ha ha\r\n\r\nWhen I enter the first...
# 84  Yeah\r\nPac, Dat Nigga Daz\r\nKurupt\r\nAll up...
# 85  Who you are,\r\nOne Nation under a thug and bu...
# 86  Eternally Thug Nigga Hilfigger made by Tommy \...
# 87  Uh oh, uh oh, oh! Oh! Oh!\r\nThey ain't ready ...
# 88  Wassup, boo? Yeah\r\nHahahaha, yeah\r\n\r\nAno...
# 89  This going out to all the females that be havi...
# 90  Quit starin' at me like an infrared nigga\r\nD...
# 91  Soon as I get home\r\nSoon as I get home\r\n\r...
# 92  2Pac:]\nTell me what the f*ck am I suppose to ...
# 93  Am I wrong cause I wanna get it on till I die?...
# 94  Welcome to the house of pain, Just Blaze nigga...
#
# [95 rows x 2 columns]

# %%
#1 2 1 2...this is just a (CSV)test
df.to_csv('tupac_lyrics.csv')

# %%
#Pass me the J, SON!
df.to_json(r'JSONLyricsExports\tupac_lyrics.json')

# %%
#Raw Word Count
df.lyrics.str.split(expand=True).stack().value_counts()
# Out:
# the            2506
# I              1975
# to             1588
# a              1461
# you            1415
# me             1152
# my             1120
# and            1114
# in              824
# I'm             755
# on              667
# it              623
# of              589
# be              549
# for             484
# get             466
# with            465
# we              464
# that            451
# your            442
# is              424
# they            407
# got             403
# up              401
# niggas          390
# like            369
# You             362
# all             358
# this            340
# see             337
#                ...
# storm             1
# fall,             1
# expert            1
# Nationwide,       1
# fatal             1
# [Daz]             1
# B.G.,             1
# J,                1
# sins,             1
# Rican             1
# thuggin           1
# thong             1
# said:             1
# confusion,        1
# 'nuff             1
# hooligan,         1
# burnin,           1
# Lou               1
# History           1
# Worms             1
# bitch;            1
# (Just             1
# Praying           1
# Breaking          1
# arguments         1
# One's             1
# hooked            1
# Huh               1
# D.A.,             1
# bound             1
# Length: 9068, dtype: int64

# %%
wordcount = df.lyrics.str.split(expand=True).stack().value_counts()

# %%
#Word.
pd.DataFrame(wordcount).to_csv('tupac_words.csv')
#wordcount.rename(columns={'Word':'Count'}, inplace=True)

# %%
#Now a value count without stop words and punctuation
df.replace(to_replace = 'I', 'the', value = "",regex=True)

# %%
#Now a value count without stop words and punctuation
 df.replace(to_replace='the','I','a','you','me','my','and','in','I''m','on','it','of','be','for','get','with','we','that','your','is','they','got','up'value="",regex=True)

# %%
import plotly.express as px #https://plot.ly/python/bar-charts/
data_tupac = px.data.gapminder().query("country == 'Canada'")
fig = px.bar(data_canada, x='year', y='pop')
fig.show()
