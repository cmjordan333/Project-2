# %%
import csv
import pandas as pd

lyrics = pd.read_csv('lyrics.csv')

# %%
lyrics.shape
# Out:
# (362237, 6)

# %%
lyrics.isnull().sum()
# Out:
# index         0
# song          2
# year          0
# artist        0
# genre         0
# lyrics    95680
# dtype: int64

# %%
modifiedLyrics=lyrics.dropna(subset=['lyrics', 'song'])

# %%
modifiedLyrics.isnull().sum()
# Out:
# index     0
# song      0
# year      0
# artist    0
# genre     0
# lyrics    0
# dtype: int64

# %%
modifiedLyrics.notnull().sum()
# Out:
# index     266556
# song      266556
# year      266556
# artist    266556
# genre     266556
# lyrics    266556
# dtype: int64

# %%
modifiedLyrics.loc[modifiedLyrics['genre'] == "Hip-Hop"]
# Out:
#          index                                           song  year  \
# 249        249                                     i-got-that  2007
# 250        250                                   8-ball-remix  2007
# 251        251                           extra-special-thankz  2007
# 252        252                                boyz-in-da-hood  2007
# 253        253                                     automoblie  2007
# 254        254                            i-d-rather-fuck-you  2007
# 255        255                         boyz-in-the-hood-remix  2007
# 256        256                                       fuck-dre  2007
# 257        257                                 trust-no-bitch  2007
# 258        258                          boyz-n-the-hood-g-mix  2007
# 259        259                               niggaz-aint-dead  2007
# 260        260                                   players-club  2007
# 261        261                          down-2-tha-last-roach  1998
# ...

# %%
modifiedLyrics.to_csv('modifiedLyrics.csv',index=False)
